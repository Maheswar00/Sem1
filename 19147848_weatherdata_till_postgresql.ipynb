# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %% [markdown]
# # Pushing data to mongo db

# %%
import pandas as pd
import json
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client['db_dap']
collection_dap = db['dap_weather']

with open('c:/Users/mahesh/weatherb.json') as f:
    all_data = json.load(f)

collection_dap.insert_many(all_data)


client.close()

# %%
#type(new_data)
all_data
# Out:
# [{'instant': 1,
#   'dteday': '01-01-2011',
#   'season': 1,
#   'yr': '0',
#   'mnth': 1,
#   'hr': '0',
#   'holiday': '0',
#   'weekday': 6,
#   'workingday': '0',
#   'weathersit': 'Clear',
#   'temp': 3.28,
#   'atemp': 3.0014,
#   'hum': 81,
#   'windspeed': '0',
#   'casual': 3,
#   'registered': 13,
#   'cnt': 16,
#   '_id': ObjectId('5ea29d48e2df653ddc9f56ce')},
#  {'instant': 2,
#   'dteday': '01-01-2011',
#   'season': 1,
#   'yr': '0',
#   'mnth': 1,
#   'hr': 1,
#   'holiday': '0',
#   'weekday': 6,
#   'workingday': '0',
#   'weathersit': 'Clear',
#   'temp': 2.34,
#   'atemp': 1.9982,
#   'hum': 80,
#   'windspeed': '0',
#   'casual': 8,
#   'registered': 32,
#   'cnt': 40,
#   '_id': ObjectId('5ea29d48e2df653ddc9f56cf')},
#  {'instant': 3,
#   'dteday': '01-01-2011',
#   'season': 1,
#   'yr': '0',
#   'mnth': 1,
#   'hr': 2,
#   'holiday': '0',
#   'weekday': 6,
#   'workingday': '0',
#   'weathersit': 'Clear',
#   'temp': 2.34,
#   'atemp': 1.9982,
#   'hum': 80,
# ...

# %%
import pandas as pd
weather = pd.DataFrame(list(collection_dap.find()))

# %%
weather.head(10)
# Out:
#                         _id  instant      dteday  season yr  mnth hr holiday  \
# 0  5ea29d48e2df653ddc9f56ce        1  01-01-2011       1  0     1  0       0
# 1  5ea29d48e2df653ddc9f56cf        2  01-01-2011       1  0     1  1       0
# 2  5ea29d48e2df653ddc9f56d0        3  01-01-2011       1  0     1  2       0
# 3  5ea29d48e2df653ddc9f56d1        4  01-01-2011       1  0     1  3       0
# 4  5ea29d48e2df653ddc9f56d2        5  01-01-2011       1  0     1  4       0
# 5  5ea29d48e2df653ddc9f56d3        6  01-01-2011       1  0     1  5       0
# 6  5ea29d48e2df653ddc9f56d4        7  01-01-2011       1  0     1  6       0
# 7  5ea29d48e2df653ddc9f56d5        8  01-01-2011       1  0     1  7       0
# 8  5ea29d48e2df653ddc9f56d6        9  01-01-2011       1  0     1  8       0
# 9  5ea29d48e2df653ddc9f56d7       10  01-01-2011       1  0     1  9       0
#
#   weekday workingday weathersit  temp   atemp hum windspeed casual registered  \
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
weather.columns
# Out:
# Index(['_id', 'instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday',
#        'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum',
#        'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
weather.isnull().sum()
# Out:
# _id           0
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# # Reoving null values

# %%
new_data_clean = weather.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
new_data_clean.isnull().sum()
# Out:
# _id           0
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
new_data_clean.shape
# Out:
# (17379, 18)

# %%
new_data_clean.columns
# Out:
# Index(['_id', 'instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday',
#        'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum',
#        'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# # Droping unnecessary columns

# %%
clean_data = new_data_clean.drop(['_id','instant','season'],axis=1)

# %%
clean_data
# Out:
#            dteday yr  mnth  hr holiday weekday workingday weathersit  temp  \
# 0      01-01-2011  0     1   0       0       6          0      Clear  3.28
# 1      01-01-2011  0     1   1       0       6          0      Clear  2.34
# 2      01-01-2011  0     1   2       0       6          0      Clear  2.34
# 3      01-01-2011  0     1   3       0       6          0      Clear  3.28
# 4      01-01-2011  0     1   4       0       6          0      Clear  3.28
# ...           ... ..   ...  ..     ...     ...        ...        ...   ...
# 17374  31-12-2012  1    12  19       0       1          1    Mistï¿½  4.22
# 17375  31-12-2012  1    12  20       0       1          1    Mistï¿½  4.22
# 17376  31-12-2012  1    12  21       0       1          1      Clear  4.22
# 17377  31-12-2012  1    12  22       0       1          1      Clear  4.22
# 17378  31-12-2012  1    12  23       0       1          1      Clear  4.22
#
#         atemp hum windspeed casual registered  cnt
# ...

# %%
clean_data.weathersit = pd.Categorical(clean_data.weathersit)
clean_data['weathersituation'] = clean_data.weathersit.cat.codes
clean_data
# Out:
#            dteday yr  mnth  hr holiday weekday workingday weathersit  temp  \
# 0      01-01-2011  0     1   0       0       6          0      Clear  3.28
# 1      01-01-2011  0     1   1       0       6          0      Clear  2.34
# 2      01-01-2011  0     1   2       0       6          0      Clear  2.34
# 3      01-01-2011  0     1   3       0       6          0      Clear  3.28
# 4      01-01-2011  0     1   4       0       6          0      Clear  3.28
# ...           ... ..   ...  ..     ...     ...        ...        ...   ...
# 17374  31-12-2012  1    12  19       0       1          1    Mistï¿½  4.22
# 17375  31-12-2012  1    12  20       0       1          1    Mistï¿½  4.22
# 17376  31-12-2012  1    12  21       0       1          1      Clear  4.22
# 17377  31-12-2012  1    12  22       0       1          1      Clear  4.22
# 17378  31-12-2012  1    12  23       0       1          1      Clear  4.22
#
#         atemp hum windspeed casual registered  cnt  weathersituation
# ...

# %%
clean_data = clean_data.drop(['weathersit'],axis=1)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17379 entries, 0 to 17378
# Data columns (total 15 columns):
# dteday              17379 non-null object
# yr                  17379 non-null object
# mnth                17379 non-null int64
# hr                  17379 non-null object
# holiday             17379 non-null object
# weekday             17379 non-null object
# workingday          17379 non-null object
# temp                17379 non-null float64
# atemp               17379 non-null float64
# hum                 17379 non-null object
# windspeed           17379 non-null object
# casual              17379 non-null object
# registered          17379 non-null object
# cnt                 17379 non-null int64
# weathersituation    17379 non-null int8
# dtypes: float64(2), int64(2), int8(1), object(10)
# memory usage: 2.0+ MB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psycopg2
from  psycopg2.extensions import connection as DB_CON
# %matplotlib inline

# %%
def get_dbCon():
        try:
            conn=psycopg2.connect(host='localhost',port=5432,database="dapdb",user='postgres',password= "NCI@maddy004")
            return conn
        except Exception as e:
            print('Db connection occurred-',e)

# %%
def select_res(table_name,conn:DB_CON):
    query="SELECT count(*) FROM "+table_name+" "
    cur=conn.cursor()
    cur.execute(query)
    query_results=cur.fetchall()
    print(query_results)
    conn.close()

# %%
table_name ='wthr'
col_name = list(clean_data.head(0))

# %% [markdown]
# # Pushing data to postgresql

# %%
#to insert data into Postgresql database

from sqlalchemy import create_engine
def insert_csv_table(df:pd.DataFrame,table_name:str,db_cols:list):
    try:
        engine = create_engine('postgresql://postgres:140896@localhost:5432/dapdb')
       
        (df.rename(columns=dict(zip(df.columns,db_cols)))
             .to_sql(name=table_name,con=engine,if_exists="append",index=False,index_label=None,schema='public'))
        print('Data insert succecssfull into the ',table_name )
    except (Exception, psycopg2.DatabaseError) as error :
            print ("Error while inserting PostgreSQL table", error)
    finally:
            #closing database connection.
            print("PostgreSQL connection is closed")

# %%
insert_csv_table(clean_data,table_name,col_name)
# Out:
# Data insert succecssfull into the  wthr
# PostgreSQL connection is closed

# %%
select_res(table_name,get_dbCon())
# Out:
# [(17379,)]

# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2

sql = "SELECT * FROM public.wthr"
try:
    dbConnection = psycopg2.connect(
        user = "postgres",
        password = "140896",
        host = "localhost",
        port = "5432",
        database = "dapdb")
    psngr1 = sqlio.read_sql_query(sql, dbConnection)
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
clean_data
# Out:
#            dteday yr  mnth  hr holiday weekday workingday  temp   atemp hum  \
# 0      01-01-2011  0     1   0       0       6          0  3.28  3.0014  81
# 1      01-01-2011  0     1   1       0       6          0  2.34  1.9982  80
# 2      01-01-2011  0     1   2       0       6          0  2.34  1.9982  80
# 3      01-01-2011  0     1   3       0       6          0  3.28  3.0014  75
# 4      01-01-2011  0     1   4       0       6          0  3.28  3.0014  75
# ...           ... ..   ...  ..     ...     ...        ...   ...     ...  ..
# 17374  31-12-2012  1    12  19       0       1          1  4.22  1.0016  60
# 17375  31-12-2012  1    12  20       0       1          1  4.22  1.0016  60
# 17376  31-12-2012  1    12  21       0       1          1  4.22  1.0016  60
# 17377  31-12-2012  1    12  22       0       1          1  4.22  1.9982  56
# 17378  31-12-2012  1    12  23       0       1          1  4.22  1.9982  65
#
#       windspeed casual registered  cnt  weathersituation
# ...
